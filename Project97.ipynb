# %%
year = int(input("Enter year: "))

if (year % 4 == 0 and year % 100 !=0) or year % 400 == 0:
  print(f"{year} is a leap year")
else:
  print(f"{year} is not a leap year")
# Out:
# Enter year: 2024
# 2024 is a leap year

# %%
height = int(input("Input height in centimeters: "))
inches = height*0.394
feet = height*0.0328
print(f"Length in inches : {round(inches,2)}")
print(f"Length in feet : {round(feet,2)}")
# Out:
# Input height in centimeters: 8
# Length in inches : 3.15
# Length in feet : 0.26
