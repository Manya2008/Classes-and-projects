# %%
import random
list_of_marks = [40,99,100,95,75,0,50,75,85,105]
count = 0 
check_num = list_of_marks[random.randint(0,9)]
for elem in list_of_marks:
  if check_num == elem:
    print(elem)
    print("number matched")
  count += 1
  #print(count)
# Out:
# 99
# number matched

# %%
import random
tuple_empty = ()
tuple_full = (40,99,100,95,75,0,50,75,85,105)
print(tuple_full[9])
# Out:
# 105
