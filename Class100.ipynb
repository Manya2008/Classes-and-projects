# %% [markdown]
# ## Phonebook

# %%
# Define Class

class Contact_Details:

    # Define Attributes of class  
    def __init__(self, name, mobile_number, email, address):
        self.contact_name = name
        self.contact_number = mobile_number
        self.email = email
        self.contact_address = address       

        # Make a dictionary of the contact details 
        self.person = {
            "name": self.contact_name,
            "mobile" : self.contact_number,
            "email": self.email,
            "address": self.contact_address
        } 

    # Define Methods of class
    def view_contact_details(self, contact_list): 
         print(contact_list)

    # Add the contact details to the list    
    def add_contact_details(self, contact_list):   
      print(self.person["email"])   
      contact_list.append(self.person)

    # REPLACE THIS COMMENT WITH CODE#

phonebook=[]
objecto = Contact_Details("manya","09099","none@gmail.com","hellostreet")
objecto.add_contact_details(phonebook)
objecto.view_contact_details(phonebook)
objective = Contact_Details("saly","09091239","niceysweet@gmail.com","hellostreet1.0")
objective.add_contact_details(phonebook)
objective.view_contact_details(phonebook)
# Out:
# none@gmail.com
# [{'name': 'manya', 'mobile': '09099', 'email': 'none@gmail.com', 'address': 'hellostreet'}]
# niceysweet@gmail.com
# [{'name': 'manya', 'mobile': '09099', 'email': 'none@gmail.com', 'address': 'hellostreet'}, {'name': 'saly', 'mobile': '09091239', 'email': 'niceysweet@gmail.com', 'address': 'hellostreet1.0'}]
