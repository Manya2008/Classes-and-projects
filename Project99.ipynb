# %%
name = input("Enter name: ")
iteration = len(name)

for i in range (0,iteration):
  for j in range (0,iteration):
    if i == j :
      print(name[j],end="")
    print("*",end=" ")
  print("")
# Out:
# Enter name: amma
# a* * * *
# * m* * *
# * * m* *
# * * * a*
