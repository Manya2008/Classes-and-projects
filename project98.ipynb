# %%
lowrange = int(input("Give lower range: "))
uprange = int(input("Give upper range: "))
divisor = int(input("Give divisor: "))

for i in range(lowrange,uprange+1):
  #print(i)
  if i % divisor == 0:
    print(i)
# Out:
# Give lower range: 3
# Give upper range: 30
# Give divisor: 4
# 4
# 8
# 12
# 16
# 20
# 24
# 28
