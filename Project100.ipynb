# %%
class moviereview:
  def __init__(self,movie,story,actors,music):
    self.movie_name = movie

    self.story_rating = story
    self.actor_rating = actors
    self.music_rating = music

    self.avg = int((self.story_rating + self.actor_rating + self.music_rating)/3)

    self.myrating = {
        "Movie name" : self.movie_name,
        "Story rating" : self.story_rating,
        "Actor rating" : self.actor_rating,
        "Music rating" : self.music_rating,
        "Avg rating" : self.avg
    }

  def add_movie_ratings(self, movie_list):
    movie_list.append(self.myrating)
  
  def avg_star_ratings (self,movie_list):
    for movie in movie_list:
      if (movie["Avg rating"] == 1):
        print("Movie is rated *")
        print(movie)
      elif (movie["Avg rating"] == 2):
        print("Movie is rated **")
        print(movie)
      elif (movie["Avg rating"] == 3):
        print("Movie is rated ***")
        print(movie)
      elif (movie["Avg rating"] == 4):
        print("Movie is rated ****")
        print(movie)
      elif (movie["Avg rating"] == 5):
        print("Movie is rated *****")
        print(movie)

moviereviews = []

done = False

while done != True :
  name = input("Enter movie name: ")

  story = int(input("Rate the story: "))
  while story < 1 or story > 5:
    print("Invalid input range 1-5")
    story = int(input("Rate the story: "))

  actor = int(input("Rate the actors: "))
  while actor < 1 or actor > 5:
    print("Invalid input range 1-5")
    actor = int(input("Rate the actors: "))
  
  music = int(input("Rate the music: "))
  while music < 1 or music > 5:
    print("Invalid input range 1-5")
    music = int(input("Rate the music: "))

  review = moviereview(name,story,actor,music)
  review.add_movie_ratings(moviereviews)

  udone=input("Do you want to continue? Y or N? ")
  if udone.lower() == "n":
    review.avg_star_ratings(moviereviews)
    done = True
# Out:
# Enter movie name: lego ninjago movie
# Rate the story: 3
# Rate the actors: 4
# Rate the music: 5
# Do you want to continue? Y or N? y
# Enter movie name: lego movie
# Rate the story: 4
# Rate the actors: 5
