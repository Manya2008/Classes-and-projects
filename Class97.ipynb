# %%
def add(x,y):
  return x+y

x=int(input("Enter one number: "))
y=int(input("Enter two number: "))

add(x,y)
# Out:
# Enter one number: 2
# Enter two number: 3
# 5

# %%
def calculate(opption):
  if opption == 1 or opption == 2 :
    print("Yet to be done")
  else:
    print("Invalid input")

no=int(input("1 or 2 "))

calculate(no)
# Out:
# 1 or 2 2
# Yet to be done
